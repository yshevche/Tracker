# %% [markdown]
# # Results

# %% [markdown]
# - What did we get from the software?
# - take screenshots of the data
# - What we were comparing at the time from the master list
# (Control, 1e6, 1e7, Mouse Illeum)

# %% [markdown]
# Interpretation of Results: Analyze the results of the model to extract meaningful insights and validate them against the initial problem. Interpretability is essential to understand how we arrived at its conclusions.
#
# Communication of Findings: Present the findings and insights to stakeholders in a clear and understandable manner. Visualization, reports, and dashboards are often used for effective communication.

# %% [markdown]
# ### Introduction to the Results

# %%
# import image module 
from IPython.display import Image

# %%
# get the image 
Image(url="./A&B_Controls.jpg")
# Out:
# <img src="./A&B_Controls.jpg"/>

# %%
# get the image 
Image(url="./C&D1e6.jpg")
# Out:
# <img src="./C&D1e6.jpg"/>

# %%
# get the image 
Image(url="./E&F1e7.jpg")
# Out:
# <img src="./E&F1e7.jpg"/>

# %% [markdown]
# Figure 2. Data points collected by Tracker were exported to and graphed in Microsoft Excel to visualize the amplitude of contractions from 3-month HIO-TESI, with and without ASCENT .  A, C, E) Data from Tracker plotted as XY Coordinate scatterplots, with distance in centimeters on the y-axis and time in seconds on the x-axis. B, D, F) Single vectors were generated by imputing the XY coordinates into the Pythagorean theorem and plotted the points with distance in centimeters on the y-axis and time in seconds on the x-axis.

# %%
# get the image 
Image(url='A_B_Single_Vector.jpg', width=1000, height=1000)
# Out:
# <img src="A_B_Single_Vector.jpg" width="1000" height="1000"/>

# %%
# get the image 
Image('1e6_SingleVectorA.jpg')

# %%
# get the image 
Image(url="1e6_SingleVectorB.jpg", width=1000, height=1000)
# Out:
# <img src="1e6_SingleVectorB.jpg" width="1000" height="1000"/>

# %%
# get the image 
Image(url="I&J.jpg", width=1000, height=1000)
# Out:
# <img src="I&J.jpg" width="1000" height="1000"/>

# %%
# get the image 
Image(url="K&L.jpg", width=1000, height=1000)
# Out:
# <img src="K&L.jpg" width="1000" height="1000"/>

# %%
# get the image 
Image(url="M&N.jpg", width=1000, height=1000)
# Out:
# <img src="M&N.jpg" width="1000" height="1000"/>

# %% [markdown]
# Figure 3. Single vector amplitude plots of 14 3-month HIO-TESI experiments. All graphs were generated by imputing the XY coordinates into the Pythagorean theorem and plotted the points with distance in centimeters on the y-axis and time in seconds on the x-axis.  A-B) Control HIO-TESI, without ASCENT, C-H) HIO-TESI injected with 1E6 ASCENT cells, I-N) HIO-TESI injected with 1E7 ASCENT cells

# %%
# get the image 
Image(url="Amplitude_Distribution_Overall.jpg", width=1000, height=1000)
# Out:
# <img src="Amplitude_Distribution_Overall.jpg" width="1000" height="1000"/>

# %% [markdown]
# Figure 4. Amplitude distribution from XY coordinate and Single Vector Data. The black line represents the median, the box represents the interquartile range, and the whiskers represent the maximum and minimum values of the data set.

# %%
# get the image 
Image(url="Maximum_Amplitudes_of_HIOTESI.jpg", width=1000, height=1000)
# Out:
# <img src="Maximum_Amplitudes_of_HIOTESI.jpg" width="1000" height="1000"/>

# %% [markdown]
# ### Future Directions

# %% [markdown]
# * Track pre-methylene blue videos
# * Average amplitude, frequency, motility index
# * Use same process to evaluate human intestine

# %% [markdown]
# Everything is from the CLIN1 Tracker figure ppt
